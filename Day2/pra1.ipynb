# %%
import requests

# %%
params = {
    "per_page":5,
    "page":1
}

# %%
response = requests.get("https://api.github.com/events", params=params)

# %%
response.url
# Out:
# 'https://api.github.com/events?per_page=5&page=1'

# %%
response.json()
# Out:
# [{'id': '46210192179',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 1779590,
#    'login': 'kilemensi',
#    'display_login': 'kilemensi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kilemensi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1779590?'},
#   'repo': {'id': 475822090,
#    'name': 'CodeForAfrica/api',
#    'url': 'https://api.github.com/repos/CodeForAfrica/api'},
#   'payload': {'action': 'closed',
#    'number': 892,
#    'pull_request': {'url': 'https://api.github.com/repos/CodeForAfrica/api/pulls/892',
#     'id': 2314912202,
#     'node_id': 'PR_kwDOHFx4Cs6J-sHK',
#     'html_url': 'https://github.com/CodeForAfrica/api/pull/892',
#     'diff_url': 'https://github.com/CodeForAfrica/api/pull/892.diff',
#     'patch_url': 'https://github.com/CodeForAfrica/api/pull/892.patch',
#     'issue_url': 'https://api.github.com/repos/CodeForAfrica/api/issues/892',
#     'number': 892,
#     'state': 'closed',
#     'locked': False,
# ...
